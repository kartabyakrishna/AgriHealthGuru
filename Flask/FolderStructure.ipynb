# %%
import os

def print_directory_structure(base_dir, indent=''):
    # List all files and subdirectories in the current directory
    items = os.listdir(base_dir)

    for item in items:
        item_path = os.path.join(base_dir, item)

        # Check if it's a directory
        if os.path.isdir(item_path):
            print(indent + f"📁 {item}/")
            print_directory_structure(item_path, indent + "  ")  # Recursive call

        # Check if it's a file
        elif os.path.isfile(item_path):
            print(indent + f"📄 {item}")

# Get the current working directory
base_directory = os.getcwd()

print(f"📁 {base_directory}/")
print_directory_structure(base_directory, "  ")
# Out:
# 📁 c:\Users\Kartabya\Downloads\Flask/
#   📄 app.py
#   📄 FolderStructure.ipynb
#   📄 model.py
#   📁 Models/
#     📄 plantDisease-resnet34.pth
#   📄 requirements.txt
#   📁 static/
#     📁 images/
#       📄 4.jpg
#       📄 b7.jpg
#     📁 styles/
#       📄 style.css
#   📁 templates/
#     📄 display.html
#     📄 index.html
#   📄 utils.py

# %%
import os

def print_directory_structure(base_dir, indent=''):
    # List all files and subdirectories in the current directory, excluding hidden files
    items = [item for item in os.listdir(base_dir) if not item.startswith('.')]

    for item in items:
        item_path = os.path.join(base_dir, item)

        # Check if it's a directory
        if os.path.isdir(item_path):
            print(indent + f"📁 {item}/")
            print_directory_structure(item_path, indent + "  ")  # Recursive call

        # Check if it's a file
        elif os.path.isfile(item_path):
            print(indent + f"📄 {item}")

# Get the current working directory
base_directory = os.getcwd()

print(f"📁 {base_directory}/")
print_directory_structure(base_directory, "  ")
# Out:
# 📁 C:\Users\Kartabya Krishna\Downloads\GitHub\DSE-labs/
#   📁 DAA-Lab/
#     📄 README.md
#     📁 Week1/
#       📄 adjacencyMatrix.cpp
#       📄 adjencyListRepresentation.cpp
#       📄 BSTimplementation.cpp
#     📁 Week10/
#       📄 DP-BinomialCoeff.cpp
#       📄 DP-FloydsAlgorithm.cpp
#       📄 DP-KnapSack01.cpp
#       📄 DP-WarshallAlgorithm.cpp
#     📁 Week11/
#       📄 11_1_Prim's.cpp
#       📄 11_2_Kruskal's.cpp
#       📄 11_3_Dijkstra's.cpp
#     📁 Week2/
#       📄 consecutiveIntGCD.cpp
#       📄 euclidsAlgo.cpp
#       📄 middleSchool2.cpp
#     📁 Week3/
#       📄 bubbleSort.cpp
#       📄 matrixMul.cpp
#       📄 selectionSort.cpp
#       📄 stringMatch.cpp
#     📁 Week4/
#       📄 Assignment2.cpp
#       📄 bfs.cpp
#       📄 DFS.cpp
#       📄 Knapsack.cpp
#     📁 Week5/
#       📄 InsertionSort.cpp
#       📄 TopologicalSort-DFS.cpp
#       📄 TopologicalSort-SourceDeletion.cpp
#     📁 Week6/
#       📄 BinaryTree Implementation.cpp
#       📄 BSTtraversal.cpp
#       📄 MergeSort.cpp
# ...
